# %% [markdown]
# <h1>Data Integration</h1>
# Merge data files into one, based off of schools listed in the Forbes Rankings. Ensure that all data has been properly transferred to one sheet.

# %%
import pandas as pd
import json
import numpy as np
import requests
import time
import csv
from collections import defaultdict

# %%
# file names
SCHOOL_FED = "federal_college_data.csv"
SCHOOL_FORBES = "forbes_rankings.csv"
SCHOOL_RATINGS = "myplan_rankings.csv"
CITY_ZIPS = "us_cities_zip_county.csv"
CITY_ZIPS_JSON = "us_cities_zip_county.json"
CITY_CRIME = "us_cities_crime.csv"
UNI_CRIME = "us_universities_crime.csv"

# merged files
SCHOOL_ALL = "schools_merged.csv"
SCHOOL_COMPLETE = "schools_complete.csv"
CITY_CRIME_ZIPS = "us_cities_crime_zips.csv"
CITY_ZIPS_JSON_UPDATED = "updated_zips.json" # city state "xx" zip_code"xxxxx"
FINAL_CITY_CRIME_ZIPS = "us_cities_crime_zips2.csv"

# %% [markdown]
# <h3>Make List of All Unique School Names</h3>

# %%
# make a list of all schools to begin the standardization process and to refer to when merging

ALL_SCHOOLS = set()

def make_schools_list(file_names: list):
    column = "school"
    for file_name in file_names:
        file_path = f"../data/{file_name}"
        df = pd.read_csv(file_path)
        df.columns = df.columns.str.lower().str.strip()
        column = column.lower().strip()

        if column not in df.columns:
            print(f"Column '{column}' not found in {file_name}")
            continue

        df[column] = df[column].astype(str).str.lower().str.strip()
        ALL_SCHOOLS.update(df[column].unique())

    return ALL_SCHOOLS

# %%
make_schools_list([SCHOOL_FED, SCHOOL_FORBES, SCHOOL_RATINGS, UNI_CRIME])
ALL_SCHOOLS_LIST = list(ALL_SCHOOLS)
print(len(ALL_SCHOOLS_LIST))
# Out:
# 6374

# %%
# quality check - make sure that ALL_SCHOOLS_LIST has no duplicates - passed!
school_set = set()
dups = []

for school in ALL_SCHOOLS_LIST:
    if school in school_set:
        dups.append(school)
    else:
        school_set.add(school)

print(dups)
# Out:
# []

# %% [markdown]
# <h3>Label School Type</h3>

# %%
# label as private or public - based on Avg. Net Price col

def label_school_type(file_name):
    file_path = f"../data/{file_name}"
    df = pd.read_csv(file_path)
    df['Type'] = None # add new column

    # label as "Public" or "Private"
    df.loc[df['Average Net Price (Public)'].notna(), 'Type'] = 'Public'
    df.loc[df['Average Net Price (Private)'].notna(), 'Type'] = 'Private'

    df.to_csv(file_path, index=False)

# %%
label_school_type(SCHOOL_FED)

# %% [markdown]
# <h3>Merge All School Files Into New File</h3>

# %%
def merge_school_data(files, new_filename):
    dfs = []

    for file_name, file_num in files.items():
        # read without changing integer types to float
        file_path = f"../data/{file_name}"
        df = pd.read_csv(file_path, dtype=str)  # read all columns as strings to preserve exact values
        df = df.rename(columns={col: f"{col}_{file_num}" for col in df.columns if col != 'school'})
        dfs.append(df)

    # merge all DataFrames on 'school' using outer join
    merged_df = dfs[0]
    for df in dfs[1:]:
        merged_df = pd.merge(merged_df, df, on='school', how='outer')
    
    # save merged df as a new csv file
    new_filepath = f"../data/merged_data/{new_filename}"
    merged_df.to_csv(new_filepath, index=False)

    return merged_df

# %%
school_files = {SCHOOL_FED: 1, SCHOOL_FORBES: 2, SCHOOL_RATINGS: 3}
merge_school_data(school_files, SCHOOL_ALL)
# Out:
#      Zip Code_1                                      school   Type_1  \
# 0         87110            a better u beauty barber academy  Private
# 1         63501     a t still university of health sciences      NaN
# 2         59526                      aaniiih nakoda college   Public
# 3         90703                            abc adult school   Public
# 4         90703             abc adult school  cabrillo lane      NaN
# ...         ...                                         ...      ...
# 6373      43701                          zane state college   Public
# 6374      60201                         zen shiatsu chicago      NaN
# 6375      84770                        zion massage college  Private
# 6376      90033                                 zms academy  Private
# 6377      98226  zorganics institute of beauty and wellness      NaN
#
#            City_1 State_1 State FIPS_1 Locale_1 Average Faculty Salary_1  \
# 0     albuquerque      NM           35     11.0                      NaN
# 1      kirksville      MO           29     33.0                  10244.0
# 2          harlem      MT           30     43.0                   4725.0
# 3        cerritos      CA            6     21.0                      NaN
# 4        cerritos      CA            6      NaN                      NaN
# ...           ...     ...          ...      ...                      ...
# 6373   zanesville      OH           39     32.0                   6001.0
# 6374     evanston      IL           17     13.0                      NaN
# 6375   st. george      UT           49     12.0                      NaN
# 6376  los angeles      CA            6     11.0                      NaN
# 6377   bellingham      WA           53     13.0                      NaN
#
#      Average SAT Score_1 Admission Rate_1  ... safety_3 teacher support_3  \
# 0                    NaN              NaN  ...      NaN               NaN
# 1                    NaN              NaN  ...      NaN               NaN
# 2                    NaN              NaN  ...      NaN               NaN
# 3                    NaN              NaN  ...      NaN               NaN
# 4                    NaN              NaN  ...      NaN               NaN
# ...                  ...              ...  ...      ...               ...
# 6373                 NaN              NaN  ...      NaN               NaN
# 6374                 NaN              NaN  ...      NaN               NaN
# 6375                 NaN              NaN  ...      NaN               NaN
# 6376                 NaN              NaN  ...      NaN               NaN
# 6377                 NaN              NaN  ...      NaN               NaN
#
#      school admin_3 prestige_3 student competitiveness_3  \
# 0               NaN        NaN                       NaN
# 1               NaN        NaN                       NaN
# 2               NaN        NaN                       NaN
# 3               NaN        NaN                       NaN
# 4               NaN        NaN                       NaN
# ...             ...        ...                       ...
# 6373            NaN        NaN                       NaN
# 6374            NaN        NaN                       NaN
# 6375            NaN        NaN                       NaN
# 6376            NaN        NaN                       NaN
# 6377            NaN        NaN                       NaN
#
#      student intelligence_3 party scene_3 greek life_3  \
# 0                       NaN           NaN          NaN
# 1                       NaN           NaN          NaN
# 2                       NaN           NaN          NaN
# 3                       NaN           NaN          NaN
# 4                       NaN           NaN          NaN
# ...                     ...           ...          ...
# 6373                    NaN           NaN          NaN
# 6374                    NaN           NaN          NaN
# 6375                    NaN           NaN          NaN
# 6376                    NaN           NaN          NaN
# 6377                    NaN           NaN          NaN
#
#      student attractiveness_3 average_3
# 0                         NaN       NaN
# 1                         NaN       NaN
# 2                         NaN       NaN
# 3                         NaN       NaN
# 4                         NaN       NaN
# ...                       ...       ...
# 6373                      NaN       NaN
# 6374                      NaN       NaN
# 6375                      NaN       NaN
# 6376                      NaN       NaN
# 6377                      NaN       NaN
#
# [6378 rows x 48 columns]

# %% [markdown]
# <h3>Make a New File With Schools that Have All Columns Filled</h3>

# %%
def get_complete_schools(filename, new_filename):
    df = pd.read_csv(f"../data/merged_data/{filename}", dtype=str)
    df = df.replace(r'^\s*$', np.nan, regex=True)

    allowed_empty = [
        'Average Net Price (Public)_1',
        'Average Net Price (Private)_1',
        'institutionType_2',
        'grade_2',
        'description_2',
        'uri_2'
    ]

    required_cols = [col for col in df.columns if col not in allowed_empty]

    # keep only rows with all cols filled
    df_complete = df.dropna(subset=required_cols).copy()

    # merge public/private price into one column
    df_complete.loc[:, 'Average Net Price_1'] = df_complete['Average Net Price (Public)_1'].combine_first(
        df_complete['Average Net Price (Private)_1']
    )

    df_complete.drop(columns=['Average Net Price (Public)_1', 'Average Net Price (Private)_1'], inplace=True)
    
    # save complete schools to a file
    new_filepath = f"../data/merged_data/{new_filename}"
    df_complete.to_csv(new_filepath, index=False)

    # find schools that have missing data
    missing_schools = df.loc[~df.index.isin(df_complete.index), 'school'].dropna().unique().tolist()

    return missing_schools

# %%
missing_schools = get_complete_schools(SCHOOL_ALL, SCHOOL_COMPLETE)

# save missing schools to a file to observe + make fuzzy matches
with open("../data/merged_data/schools_missing_data.csv", "w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    for school in missing_schools:
        writer.writerow([school])

# %% [markdown]
# <h3>Add Zip Codes To Crime Doc</h3>

# %%
# to assess school safety, add zip codes to crime doc and compare to school zip code
def add_zips(csv_file, json_file, output_file):
    
    df = pd.read_csv(csv_file)
    with open(f"../data/{json_file}", 'r') as f: #load JSON zips
        zip_records = json.load(f)

    # create dict from JSON values {(city, state): postal_code}
    zip_lookup = {}
    for entry in zip_records:
        city = entry['City'].strip().lower()
        state = entry['State'].strip().lower()
        zip_code = entry['Postal Code']
        key = (city, state)
        if key not in zip_lookup:
            zip_lookup[key] = zip_code  # only take first if multiple

    # def get_zip(row):
    #     city = str(row["City"])
    #     state = str(row["State"])
    #     return zip_lookup.get((city, state), None)
    
    def get_zip(row):
        city = str(row["City"]).strip().lower()
        state = str(row["State"]).strip().lower()
        return zip_lookup.get((city, state), None)

    df["Zip Code"] = df.apply(get_zip, axis=1) #axis 1 applies func to each row, axis 0 applies func to each column
    df.to_csv(f"../data/merged_data/{output_file}", index=False)

# %%
add_zips(f"../data/{CITY_CRIME}", CITY_ZIPS_JSON, CITY_CRIME_ZIPS)

# %%
# check -- count amount of empty zip codes in file
def count_missing_zips(filename):
    file_path = f"../data/merged_data/{filename}"
    df = pd.read_csv(filename)
    
    # count rows where Zip Code is missing or blank
    missing_count = df["Zip Code"].isna().sum() + (df["Zip Code"].astype(str).str.strip() == "").sum()
    
    print(f"Missing Zip Code entries: {missing_count}")
    return missing_count

# %%
count_missing_zips(f"../data/merged_data/{CITY_CRIME_ZIPS}")
# Out:
# Missing Zip Code entries: 8289
# 8289

# %%
# not all zip codes were added
# use zip code api to fill remaining zips

zips_dict = {}

# query Zippopotam.us API and return the first ZIP code if found
# example request http://api.zippopotam.us/us/ny/new%20york

def get_zip_codes_from_api(state: str, city: str):

    try:
        url = f"http://api.zippopotam.us/us/{state.lower()}/{city.lower().replace(' ', '%20')}"
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            return data["places"][0]["post code"]  # Return the first ZIP code
    except Exception as e:
        print(f"API error for {city}, {state}: {e}")
    return None

def fill_missing_zips(filename: str):
    
    df = pd.read_csv(filename)

    if "Zip Code" not in df.columns: #check for zip code column
        df["Zip Code"] = None

    # iterate through rows where Zip Code is missing
    for i, row in df[df["Zip Code"].isna()].iterrows(): # add city and state to a dict if zip code is missing
        city = str(row["City"]).strip()
        state = str(row["State"]).strip()
        zips_dict[city] = state

    return f"Zip Dictionary complete. {len(zips_dict)} entries."

def add_zips_dict(cities_dict: dict):
    updated_dict = {}

    for city, state in cities_dict.items():
        zip_code = get_zip_codes_from_api(state, city)
        if zip_code:
            updated_dict[city] = {
                'state': state,
                'zip_code': zip_code
            }
            print(f"{city.title()}, {state.upper()} → ZIP: {zip_code or 'N/A'}")
        time.sleep(1) # delay to avoid rate-limiting

    return updated_dict

# %%
print(fill_missing_zips(f"../data/merged_data/{CITY_CRIME_ZIPS}"))
test_dict = {'abbeville': 'sc', 'addison': 'al', 'andalusia': 'al', 'anniston': 'al'}
print(zips_dict)
city_zip_dict = add_zips_dict(zips_dict)
print(len(city_zip_dict))
# Out:
# Zip Dictionary complete. 6459 entries.
# {'abbeville': 'SC', 'adamsville': 'TN', 'addison': 'nan', 'alabaster': 'AL', 'albertville': 'AL', 'alexander city': 'AL', 'aliceville': 'AL', 'andalusia': 'AL', 'anniston': 'AL', 'arab': 'AL', 'ardmore': 'nan', 'argo': 'AL', 'arley': 'AL', 'ashland': 'nan', 'ashville': 'nan', 'athens': 'nan', 'atmore': 'AL', 'attalla': 'AL', 'auburn': 'nan', 'bay minette': 'AL', 'bayou la batre': 'AL', 'bear creek': 'AL', 'berry': 'AL', 'bessemer': 'AL', 'birmingham': 'nan', 'blountsville': 'AL', 'brent': 'AL', 'brewton': 'AL', 'bridgeport': 'nan', 'brighton': 'nan', 'brilliant': 'AL', 'brookside': 'AL', 'brookwood': 'AL', 'brundidge': 'AL', 'butler': 'nan', 'calera': 'nan', 'carrollton': 'nan', 'cedar bluff': 'AL', 'centre': 'AL', 'centreville': 'AL', 'chatom': 'AL', 'cherokee': 'nan', 'chickasaw': 'AL', 'citronelle': 'AL', 'clanton': 'AL', 'clayton': 'nan', 'cleveland': 'nan', 'collinsville': 'nan', 'columbiana': 'nan', 'coosada': 'AL', 'cordova': 'AK', 'cottonwood': 'AZ', 'courtland': 'AL', 'creola': 'AL', 'cuba': 'nan', 'cullman': 'AL', 'dadeville': 'AL', 'daphne': 'AL', 'dauphin island': 'AL', 'decatur': 'nan', 'demopolis': 'AL', 'dora': 'AL', 'dothan': 'AL', 'double springs': 'AL', 'douglas': 'nan', 'east brewton': 'AL', 'eclectic': 'AL', 'elba': 'AL', 'elberta': 'AL', 'enterprise': 'AL', 'eufaula': 'nan', 'evergreen': 'nan', 'excel': 'AL', 'fairhope': 'AL', 'falkville
# Avondale, AZ → ZIP: 85323
# Bisbee, AZ → ZIP: 85603
# Buckeye, AZ → ZIP: 85326
# Bullhead City, AZ → ZIP: 86429
# Camp Verde, AZ → ZIP: 86322
# Casa Grande, AZ → ZIP: 85122
# Chino Valley, AZ → ZIP: 86323
# Clarkdale, AZ → ZIP: 86324
# Coolidge, AZ → ZIP: 85128
# El Mirage, AZ → ZIP: 85335
# Eloy, AZ → ZIP: 85131
# Flagstaff, AZ → ZIP: 86001
# Fredonia, KS → ZIP: 66736
# Globe, AZ → ZIP: 85501
# Goodyear, AZ → ZIP: 85338
# Huachuca City, AZ → ZIP: 85616
# Jerome, ID → ZIP: 83338
# Kingman, KS → ZIP: 67068
# Lake Havasu City, AZ → ZIP: 86403
# Litchfield Park, AZ → ZIP: 85340
# Marana, AZ → ZIP: 85653
# Maricopa, AZ → ZIP: 85138
# Mesa, AZ → ZIP: 85201
# Nogales, AZ → ZIP: 85621
# Oro Valley, AZ → ZIP: 85755
# Page, AZ → ZIP: 86040
# Paradise Valley, AZ → ZIP: 85253
# Peoria, IL → ZIP: 61601
# Prescott Valley, AZ → ZIP: 86312
# Queen Creek, AZ → ZIP: 85140
# Sahuarita, AZ → ZIP: 85629
# San Luis, AZ → ZIP: 85349
# Scottsdale, AZ → ZIP: 85250
# Show Low, AZ → ZIP: 85901
# Sierra Vista, AZ → ZIP: 85635
# Somerton, AZ → ZIP: 85350
# Surprise, AZ → ZIP: 85374
# Tempe, AZ → ZIP: 85280
# Thatcher, AZ → ZIP: 85552
# Wickenburg, AZ → ZIP: 85358
# Willcox, AZ → ZIP: 85643
# Williams, CA → ZIP: 95987
# Yuma, AZ → ZIP: 85364
# Alexander, AR → ZIP: 72002
# Amity, AR → ZIP: 71921
# Arkadelphia, AR → ZIP: 71923
# Ashdown, AR → ZIP: 71822
# Ash Flat, AR → ZIP: 72513
# Atkins, AR → ZIP: 72822
# Bald Knob, AR → ZIP: 72010
# Barling, AR → ZIP: 72923
# Bay, AR → ZIP: 72088
# Beebe, AR → ZIP: 72012
# Bella Vista, AR → ZIP: 72714
# Bentonville, AR → ZIP: 72712
# Black Rock, AR → ZIP: 72415
# Blytheville, AR → ZIP: 72315
# Bono, AR → ZIP: 72416
# Brinkley, AR → ZIP: 72021
# Brookland, AR → ZIP: 72417
# Bryant, AR → ZIP: 72022
# Bull Shoals, AR → ZIP: 72619
# Cabot, AR → ZIP: 72023
# Caraway, AR → ZIP: 72419
# Cave Springs, AR → ZIP: 72718
# Centerton, AR → ZIP: 72719
# Cherokee Village, AR → ZIP: 72525
# Cherry Valley, IL → ZIP: 61016
# Clarendon, AR → ZIP: 72029
# Cotter, AR → ZIP: 72626
# Crossett, AR → ZIP: 71635
# Dardanelle, AR → ZIP: 72834
# De Queen, AR → ZIP: 71832
# Des Arc, AR → ZIP: 72040
# De Valls Bluff, AR → ZIP: 72041
# Diamond City, AR → ZIP: 72630
# Diaz, AR → ZIP: 72043
# Earle, AR → ZIP: 72331
# El Dorado, KS → ZIP: 67042
# Elkins, AR → ZIP: 72727
# England, AR → ZIP: 72046
# Eudora, KS → ZIP: 66025
# Eureka Springs, AR → ZIP: 72631
# Fairfield Bay, AR → ZIP: 72088
# Flippin, AR → ZIP: 72634
# Fordyce, AR → ZIP: 71742
# Forrest City, AR → ZIP: 72335
# Fort Smith, AR → ZIP: 72901
# Gassville, AR → ZIP: 72635
# Gentry, AR → ZIP: 72734
# Gillett, AR → ZIP: 72055
# Gosnell, AR → ZIP: 72319
# Gravette, AR → ZIP: 72736
# Green Forest, AR → ZIP: 72638
# Greenland, AR → ZIP: 72737
# Gurdon, AR → ZIP: 71743
# Hackett, AR → ZIP: 72937
# Hardy, AR → ZIP: 72542
# Hazen, AR → ZIP: 72064
# Heber Springs, AR → ZIP: 72543
# Higginson, AR → ZIP: 72068
# Highland, IN → ZIP: 46322
# Hope, AR → ZIP: 71801
# Hoxie, AR → ZIP: 72433
# Humphrey, AR → ZIP: 72073
# Johnson, AR → ZIP: 72741
# Jonesboro, AR → ZIP: 72401
# Judsonia, AR → ZIP: 72081
# Kensett, AR → ZIP: 72082
# Lake Village, AR → ZIP: 71653
# Lavaca, AR → ZIP: 72941
# Leachville, AR → ZIP: 72438
# Lead Hill, AR → ZIP: 72644
# Lepanto, AR → ZIP: 72354
# Little Rock, AR → ZIP: 72099
# Lonoke, AR → ZIP: 72086
# Luxora, AR → ZIP: 72358
# Malvern, AR → ZIP: 72104
# Mammoth Spring, AR → ZIP: 72554
# Manila, AR → ZIP: 72442
# Marianna, AR → ZIP: 72360
# Marked Tree, AR → ZIP: 72365
# Marmaduke, AR → ZIP: 72443
# Maumelle, AR → ZIP: 72113
# Mayflower, AR → ZIP: 72106
# Mena, AR → ZIP: 71953
# Monette, AR → ZIP: 72447
# Morrilton, AR → ZIP: 72110
# Mountain Home, ID → ZIP: 83647
# Mulberry, AR → ZIP: 72947
# Nashville, GA → ZIP: 31639
# Norfork, AR → ZIP: 72658
# North Little Rock, AR → ZIP: 72114
# Ola, AR → ZIP: 72047
# Paragould, AR → ZIP: 72450
# Parkin, AR → ZIP: 72373
# Pea Ridge, AR → ZIP: 72751
# Piggott, AR → ZIP: 72454
# Pine Bluff, AR → ZIP: 71601
# Plumerville, AR → ZIP: 72127
# Pocahontas, AR → ZIP: 72455
# Ravenden, AR → ZIP: 72459
# Redfield, AR → ZIP: 72132
# Rose Bud, AR → ZIP: 72137
# Searcy, AR → ZIP: 72143
# Siloam Springs, AR → ZIP: 72761
# Smackover, AR → ZIP: 71762
# Stamps, AR → ZIP: 71860
# Stuttgart, AR → ZIP: 72160
# Swifton, AR → ZIP: 72471
# Tontitown, AR → ZIP: 72770
# Trumann, AR → ZIP: 72472
# Tuckerman, AR → ZIP: 72473
# Tyronza, AR → ZIP: 72386
# Van Buren, AR → ZIP: 72956
# Vilonia, AR → ZIP: 72173
# Waldron, AR → ZIP: 72958
# Walnut Ridge, AR → ZIP: 72476
# Ward, AR → ZIP: 72176
# Weiner, AR → ZIP: 72479
# Lake Helen, FL → ZIP: 32744
# Lake Mary, FL → ZIP: 32746
# Lake Park, GA → ZIP: 31636
# Lake Wales, FL → ZIP: 33853
# Largo, FL → ZIP: 33037
# Longboat Key, FL → ZIP: 34228
# Longwood, FL → ZIP: 32750
# Lynn Haven, FL → ZIP: 32444
# Maitland, FL → ZIP: 32751
# Marco Island, FL → ZIP: 33937
# Mascotte, FL → ZIP: 34753
# Miramar, FL → ZIP: 32550
# Neptune Beach, FL → ZIP: 32266
# North Miami Beach, FL → ZIP: 33160
# North Palm Beach, FL → ZIP: 33408
# North Port, FL → ZIP: 34286
# Ocala, FL → ZIP: 34470
# Okeechobee, FL → ZIP: 34972
# Oldsmar, FL → ZIP: 34677
# Oviedo, FL → ZIP: 32762
# Pahokee, FL → ZIP: 33476
# Palatka, FL → ZIP: 32131
# Palm Bay, FL → ZIP: 32905
# Palmetto, GA → ZIP: 30268
# Panama City, FL → ZIP: 32401
# Pensacola, FL → ZIP: 32501
# Pinellas Park, FL → ZIP: 33780
# Safety Harbor, FL → ZIP: 34695
# Satellite Beach, FL → ZIP: 32937
# Sebastian, FL → ZIP: 32958
# South Bay, FL → ZIP: 33493
# Tampa, FL → ZIP: 33601
# Tarpon Springs, FL → ZIP: 34688
# Tavares, FL → ZIP: 32778
# Titusville, FL → ZIP: 32780
# Wauchula, FL → ZIP: 33873
# West Palm Beach, FL → ZIP: 33401
# Wildwood, FL → ZIP: 34785
# Winter Haven, FL → ZIP: 33880
# Winter Park, FL → ZIP: 32789
# Zephyrhills, FL → ZIP: 33539
# Acworth, GA → ZIP: 30101
# Adairsville, GA → ZIP: 30103
# Alapaha, GA → ZIP: 31622
# Alpharetta, GA → ZIP: 30004
# Alto, GA → ZIP: 30510
# Americus, GA → ZIP: 31709
# Bainbridge, GA → ZIP: 31717
# Ball Ground, GA → ZIP: 30107
# Baxley, GA → ZIP: 31513
# Blackshear, GA → ZIP: 31516
# Blairsville, GA → ZIP: 30512
# Braselton, GA → ZIP: 30517
# Bremen, GA → ZIP: 30110
# Brooklet, GA → ZIP: 30415
# Broxton, GA → ZIP: 31519
# Byron, GA → ZIP: 31008
# Cairo, GA → ZIP: 31728
# Camilla, GA → ZIP: 31730
# Cartersville, GA → ZIP: 30120
# Cave Spring, GA → ZIP: 30124
# Cedartown, GA → ZIP: 30125
# Chatsworth, GA → ZIP: 30705
# Claxton, GA → ZIP: 30417
# Cochran, GA → ZIP: 31014
# Conyers, GA → ZIP: 30012
# Cordele, GA → ZIP: 31010
# Davisboro, GA → ZIP: 31018
# Demorest, GA → ZIP: 30535
# Doerun, GA → ZIP: 31744
# Donalsonville, GA → ZIP: 31745
# Douglasville, GA → ZIP: 30133
# East Ellijay, GA → ZIP: 30539
# Eastman, GA → ZIP: 31023
# Eatonton, GA → ZIP: 31024
# Elberton, GA → ZIP: 30635
# Ellaville, GA → ZIP: 31806
# Ellijay, GA → ZIP: 30536
# Enigma, GA → ZIP: 31749
# Eton, GA → ZIP: 30059
# Fitzgerald, GA → ZIP: 31750
# Flowery Branch, GA → ZIP: 30542
# Folkston, GA → ZIP: 31537
# Franklin Springs, GA → ZIP: 30639
# Grantville, GA → ZIP: 30220
# Gray, GA → ZIP: 30017
# Griffin, GA → ZIP: 30223
# Grovetown, GA → ZIP: 30813
# Hahira, GA → ZIP: 31632
# Hartwell, GA → ZIP: 30643
# Hazlehurst, GA → ZIP: 31539
# Helen, GA → ZIP: 30545
# Hephzibah, GA → ZIP: 30815
# Hiram, GA → ZIP: 30141
# Hogansville, GA → ZIP: 30230
# Homerville, GA → ZIP: 31634
# Kennesaw, GA → ZIP: 30144
# Kingsland, GA → ZIP: 31548
# Lagrange, IN → ZIP: 46761
# Lavonia, GA → ZIP: 30553
# Leary, GA → ZIP: 31762
# Lilburn, GA → ZIP: 30047
# Loganville, GA → ZIP: 30052
# Mcdonough, GA → ZIP: 30252
# Milledgeville, IL → ZIP: 61051
# Millen, GA → ZIP: 30442
# Morrow, GA → ZIP: 30260
# Moultrie, GA → ZIP: 31768
# Newnan, GA → ZIP: 30254
# Norcross, GA → ZIP: 30003
# Oakwood, IL → ZIP: 61858
# Ocilla, GA → ZIP: 31774
# Oglethorpe, GA → ZIP: 30742
# Omega, GA → ZIP: 31775
# Peachtree City, GA → ZIP: 30269
# Pendergrass, GA → ZIP: 30567
# Pine Mountain, GA → ZIP: 31822
# Richmond Hill, GA → ZIP: 31324
# Rincon, GA → ZIP: 31326
# Ringgold, GA → ZIP: 30736
# Rockmart, GA → ZIP: 30153
# Sandersville, GA → ZIP: 31082
# Senoia, GA → ZIP: 30276
# Snellville, GA → ZIP: 30039
# Statesboro, GA → ZIP: 30458
# Stone Mountain, GA → ZIP: 30083
# Sylvester, GA → ZIP: 31791
# Toccoa, GA → ZIP: 30577
# Tybee Island, GA → ZIP: 31328
# Villa Rica, GA → ZIP: 30180
# Warner Robins, GA → ZIP: 31088
# Waycross, GA → ZIP: 31501
# Winder, GA → ZIP: 30680
# Honolulu, HI → ZIP: 96801
# American Falls, ID → ZIP: 83211
# Blackfoot, ID → ZIP: 83221
# Boise, ID → ZIP: 83701
# Bonners Ferry, ID → ZIP: 83805
# Buhl, ID → ZIP: 83316
# Challis, ID → ZIP: 83226
# Emmett, ID → ZIP: 83617
# Filer, ID → ZIP: 83328
# Gooding, ID → ZIP: 83330
# Hagerman, ID → ZIP: 83332
# Heyburn, ID → ZIP: 83336
# Homedale, ID → ZIP: 83628
# Idaho Falls, ID → ZIP: 83401
# Kellogg, ID → ZIP: 83837
# Ketchum, ID → ZIP: 83340
# Mccall, ID → ZIP: 83638
# Moscow, ID → ZIP: 83843
# Nampa, ID → ZIP: 83651
# Osburn, ID → ZIP: 83849
# Payette, ID → ZIP: 83661
# Pocatello, ID → ZIP: 83201
# Post Falls, ID → ZIP: 83854
# Priest River, ID → ZIP: 83856
# Rathdrum, ID → ZIP: 83858
# Rexburg, ID → ZIP: 83440
# Rigby, ID → ZIP: 83442
# Rupert, ID → ZIP: 83350
# Salmon, ID → ZIP: 83467
# Vernon Hills, IL → ZIP: 60061
# Virden, IL → ZIP: 62690
# Warrenville, IL → ZIP: 60555
# Watseka, IL → ZIP: 60970
# Wauconda, IL → ZIP: 60084
# Waukegan, IL → ZIP: 60079
# Westchester, IL → ZIP: 60154
# West Chicago, IL → ZIP: 60185
# Western Springs, IL → ZIP: 60558
# Westmont, IL → ZIP: 60559
# Wheaton, IL → ZIP: 60187
# Williamsville, IL → ZIP: 62693
# Willowbrook, IL → ZIP: 60527
# Wilmette, IL → ZIP: 60091
# Winnetka, IL → ZIP: 60093
# Wonder Lake, IL → ZIP: 60097
# Wood Dale, IL → ZIP: 60191
# Woodridge, IL → ZIP: 60517
# Wood River, IL → ZIP: 62095
# Worden, IL → ZIP: 62097
# Worth, IL → ZIP: 60043
# Yorkville, IL → ZIP: 60560
# Zion, IL → ZIP: 60099
# Angola, IN → ZIP: 46703
# Bargersville, IN → ZIP: 46106
# Beech Grove, IN → ZIP: 46107
# Brownsburg, IN → ZIP: 46112
# Cedar Lake, IN → ZIP: 46303
# Chesterton, IN → ZIP: 46304
# Crawfordsville, IN → ZIP: 47933
# Crown Point, IN → ZIP: 46307
# Dyer, IN → ZIP: 46311
# East Chicago, IN → ZIP: 46312
# Edinburgh, IN → ZIP: 46124
# Elkhart, IN → ZIP: 46514
# Fishers, IN → ZIP: 46037
# Fort Wayne, IN → ZIP: 46801
# Gary, IN → ZIP: 46401
# Gas City, IN → ZIP: 46933
# Griffith, IN → ZIP: 46319
# Huntingburg, IN → ZIP: 47542
# Indianapolis, IN → ZIP: 46201
# Jeffersonville, IN → ZIP: 47130
# Kendallville, IN → ZIP: 46755
# Knightsville, IN → ZIP: 47857
# Knox, IN → ZIP: 46534
# Kokomo, IN → ZIP: 46901
# Linton, IN → ZIP: 47441
# Logansport, IN → ZIP: 46947
# Michigan City, IN → ZIP: 46360
# Mishawaka, IN → ZIP: 46544
# Muncie, IN → ZIP: 47302
# Munster, IN → ZIP: 46321
# Nappanee, IN → ZIP: 46550
# New Palestine, IN → ZIP: 46163
# Noblesville, IN → ZIP: 46060
# North Vernon, IN → ZIP: 47265
# North Webster, IN → ZIP: 46555
# Schererville, IN → ZIP: 46375
# Shipshewana, IN → ZIP: 46565
# Tell City, IN → ZIP: 47586
# Terre Haute, IN → ZIP: 47801
# Topeka, KS → ZIP: 66601
# Valparaiso, IN → ZIP: 46383
# Vincennes, IN → ZIP: 47591
# West Lafayette, IN → ZIP: 47906
# Whiteland, IN → ZIP: 46184
# Whitestown, IN → ZIP: 46075
# Whiting, IN → ZIP: 46394
# Yorktown, IN → ZIP: 47396
# Zionsville, IN → ZIP: 46077
# Adel, IA → ZIP: 50003
# Albia, IA → ZIP: 52531
# Ames, IA → ZIP: 50010
# Anamosa, IA → ZIP: 52205
# Ankeny, IA → ZIP: 50015
# Atlantic, IA → ZIP: 50022
# Bettendorf, IA → ZIP: 52722
# Blue Grass, IA → ZIP: 52726
# Buffalo, WY → ZIP: 82834
# Camanche, IA → ZIP: 52730
# Carter Lake, IA → ZIP: 51510
# Cedar Rapids, IA → ZIP: 52401
# Charles City, IA → ZIP: 50616
# Clarence, IA → ZIP: 52216
# Clarinda, IA → ZIP: 51632
# Clarion, IA → ZIP: 50525
# Clear Lake, IA → ZIP: 50428
# Clive, IA → ZIP: 50325
# Coralville, IA → ZIP: 52241
# Council Bluffs, IA → ZIP: 51501
# Creston, IA → ZIP: 50801
# Decorah, IA → ZIP: 52101
# Dubuque, IA → ZIP: 52001
# Dyersville, IA → ZIP: 52040
# Dysart, IA → ZIP: 52224
# Earlham, IA → ZIP: 50072
# Eldora, IA → ZIP: 50627
# Eldridge, IA → ZIP: 52748
# Emmetsburg, IA → ZIP: 50536
# Estherville, IA → ZIP: 51334
# Evansdale, IA → ZIP: 50707
# Fort Dodge, IA → ZIP: 50501
# Fort Madison, IA → ZIP: 52627
# Gowrie, IA → ZIP: 50543
# Grinnell, IA → ZIP: 50112
# Grundy Center, IA → ZIP: 50638
# Hiawatha, KS → ZIP: 66434
# Huxley, IA → ZIP: 50124
# Iowa City, IA → ZIP: 52240
# Iowa Falls, IA → ZIP: 50126
# Keokuk, IA → ZIP: 52632
# Le Claire, IA → ZIP: 52753
# Le Mars, IA → ZIP: 51031
# Maquoketa, IA → ZIP: 52060
# Marshalltown, IA → ZIP: 50158
# Mechanicsville, IA → ZIP: 52306
# Missouri Valley, IA → ZIP: 51555
# Mitchellville, IA → ZIP: 50169
# Muscatine, IA → ZIP: 52761
# New Sharon, IA → ZIP: 50207
# North Liberty, IA → ZIP: 52317
# Oelwein, IA → ZIP: 50662
# Osage, IA → ZIP: 50461
# Oskaloosa, IA → ZIP: 52577
# Ottumwa, IA → ZIP: 52501
# Panora, IA → ZIP: 50216
# Pella, IA → ZIP: 50219
# Peosta, IA → ZIP: 52068
# Polk City, IA → ZIP: 50226
# Postville, IA → ZIP: 52162
# Prairie City, IA → ZIP: 50228
# Rock Valley, IA → ZIP: 51247
# Sabula, IA → ZIP: 52070
# Sac City, IA → ZIP: 50583
# Sheldon, IA → ZIP: 51201
# Sigourney, IA → ZIP: 52591
# Sioux Center, IA → ZIP: 51250
# Sioux City, IA → ZIP: 51101
# Storm Lake, IA → ZIP: 50588
# Story City, IA → ZIP: 50248
# Urbandale, IA → ZIP: 50322
# Van Meter, IA → ZIP: 50261
# Walcott, IA → ZIP: 52773
# Waukee, IA → ZIP: 50263
# Waukon, IA → ZIP: 52172
# Webster City, IA → ZIP: 50595
# West Burlington, IA → ZIP: 52655
# West Des Moines, IA → ZIP: 50265
# Windsor Heights, IA → ZIP: 50324
# Arkansas City, KS → ZIP: 67005
# Atchison, KS → ZIP: 66002
# Baldwin City, KS → ZIP: 66006
# Basehor, KS → ZIP: 66007
# Baxter Springs, KS → ZIP: 66713
# Bonner Springs, KS → ZIP: 66012
# Chanute, KS → ZIP: 66720
# Cherryvale, KS → ZIP: 67335
# Clay Center, KS → ZIP: 67432
# Coffeyville, KS → ZIP: 67337
# Concordia, KS → ZIP: 66901
# Council Grove, KS → ZIP: 66846
# Dodge City, KS → ZIP: 67801
# Ellinwood, KS → ZIP: 67526
# Fort Scott, KS → ZIP: 66701
# Garnett, KS → ZIP: 66032
# Goddard, KS → ZIP: 67052
# Goodland, KS → ZIP: 67735
# Halstead, KS → ZIP: 67056
# Hesston, KS → ZIP: 67062
# Hoisington, KS → ZIP: 67544
# Holton, KS → ZIP: 66436
# Horton, KS → ZIP: 66439
# Hugoton, KS → ZIP: 67951
# Iola, KS → ZIP: 66749
# Larned, KS → ZIP: 67550
# Leavenworth, KS → ZIP: 66027
# Lindsborg, KS → ZIP: 67456
# Lyons, KS → ZIP: 67554
# Maize, KS → ZIP: 67101
# Mcpherson, KS → ZIP: 67460
# Mulvane, KS → ZIP: 67110
# Neodesha, KS → ZIP: 66757
# Olathe, KS → ZIP: 66051
# Osage City, KS → ZIP: 66523
# Osawatomie, KS → ZIP: 66064
# Paola, KS → ZIP: 66071
# Pratt, KS → ZIP: 67124
# Rose Hill, KS → ZIP: 67133
# Tonganoxie, KS → ZIP: 66086
# Ulysses, KS → ZIP: 67880
# Valley Center, KS → ZIP: 67147
# Wamego, KS → ZIP: 66547
# Wichita, KS → ZIP: 67201
# Adairville, KY → ZIP: 42202
# Addis, LA → ZIP: 70710
# Baker, MT → ZIP: 59313
# Aberdeen, WA → ZIP: 98520
# Abington, MA → ZIP: 02351
# Adams, WI → ZIP: 53910
# Barre, VT → ZIP: 05641
# Adrian, MO → ZIP: 64720
# Ackerman, MS → ZIP: 39735
# Boulder City, NV → ZIP: 89005
# Alamogordo, NM → ZIP: 88310
# Berthold, ND → ZIP: 58718
# Achille, OK → ZIP: 74720
# Abbottstown, PA → ZIP: 17301
# Abernathy, TX → ZIP: 79311
# Abingdon, VA → ZIP: 24210
# Alderson, WV → ZIP: 24910
# 1414

# %%
# save new dict to json file

def save_json(cities_dict, filename):
    formatted = [] # convert nested dict to list of dicts
    for city, info in cities_dict.items():
        zip_code = info.get("zip_code")
        state = info.get("state")
        
        if zip_code and state:
            formatted.append({
                "City": city.lower(),
                "Postal Code": zip_code,
                "State": state.lower()
            })
            
    
    # Save as a JSON file
    with open(filename, "w") as f:
        json.dump(formatted, f, indent=2)

# %%
save_json(city_zip_dict, f"../data/{CITY_ZIPS_JSON_UPDATED}")

# %%
add_zips(f"../data/merged_data/{CITY_CRIME_ZIPS}", f"../data/{CITY_ZIPS_JSON_UPDATED}", FINAL_CITY_CRIME_ZIPS)
count_missing_zips(f"../data/merged_data/{FINAL_CITY_CRIME_ZIPS}")# zip code api added 1,090 new zip codes
# Out:
# Missing Zip Code entries: 6953
# 6953

# %% [markdown]
# <h3>Add Aggregated Crime Metrics</h3>

# %%
def get_sum_crime_rates(filename):
    df = pd.read_csv(filename)
    df.drop(columns=['Unnamed: 13'], inplace=True) #drop unnecessary column
    df.columns = df.columns.str.replace('\n', ' ')
    print(list(df))

    cols_to_sum = [
        'Violent crime', 'Murder and nonnegligent manslaughter', 'Rape', 
        'Robbery', 'Aggravated assault', 'Property crime', 'Burglary', 
        'Larceny- theft', 'Motor vehicle theft', 'Arson1'
    ]

    # sum Crime per City
    df[cols_to_sum] = df[cols_to_sum].apply(pd.to_numeric, errors='coerce')
    df['Crime Sum'] = df[cols_to_sum].sum(axis=1)

    # calculate crime ratio based on sum & population
    df['Population'] = df['Population'].astype(str).str.replace(',', '')
    df['Population'] = pd.to_numeric(df['Population'], errors='coerce')
    df = df[df['Population'] > 0]
    
    df['Crime Ratio'] = df['Crime Sum'] / df['Population']

    df.to_csv(filename, index=False)
    return df

# %%
get_sum_crime_rates(f"../data/merged_data/{FINAL_CITY_CRIME_ZIPS}")
# Out:
# ['State', 'City', 'Population', 'Violent crime', 'Murder and nonnegligent manslaughter', 'Rape', 'Robbery', 'Aggravated assault', 'Property crime', 'Burglary', 'Larceny- theft', 'Motor vehicle theft', 'Arson1', 'Zip Code']
#      State         City  Population  Violent crime  \
# 0       AL    abbeville      2371.0            6.0
# 1       AL   adamsville      4158.0           17.0
# 2       AL      addison       674.0            3.0
# 3       AL    alabaster     34120.0           37.0
# 4       AL  albertville     22887.0           68.0
# ...    ...          ...         ...            ...
# 8360   NaN     sheridan     19472.0           19.0
# 8361   NaN  thermopolis      2692.0            1.0
# 8362   NaN   torrington      6148.0           12.0
# 8363   NaN        upton       904.0            1.0
# 8364   NaN      worland      4812.0            4.0
#
#       Murder and nonnegligent manslaughter  Rape  Robbery  Aggravated assault  \
# 0                                      0.0   0.0      0.0                 6.0
# 1                                      0.0   1.0      5.0                11.0
# 2                                      0.0   1.0      0.0                 2.0
# 3                                      1.0   1.0      5.0                30.0
# 4                                      0.0  11.0      3.0                54.0
# ...                                    ...   ...      ...                 ...
# 8360                                   2.0   2.0      1.0                14.0
# 8361                                   0.0   0.0      1.0                 0.0
# 8362                                   0.0   6.0      0.0                 6.0
# 8363                                   0.0   0.0      0.0                 1.0
# 8364                                   0.0   2.0      0.0                 2.0
#
#       Property crime  Burglary  Larceny- theft  Motor vehicle theft  Arson1  \
# 0               27.0       6.0            21.0                  0.0     0.0
# 1              201.0      23.0           158.0                 20.0     0.0
# 2               14.0       2.0            10.0                  2.0     0.0
# 3              551.0      16.0           518.0                 17.0     2.0
# 4              415.0      40.0           315.0                 60.0     6.0
# ...              ...       ...             ...                  ...     ...
# 8360           220.0      20.0           191.0                  9.0     1.0
# 8361            17.0       5.0            12.0                  0.0     0.0
# 8362            96.0      14.0            72.0                 10.0     0.0
# 8363            14.0       0.0            13.0                  1.0     0.0
# 8364            22.0       1.0            20.0                  1.0     0.0
#
#       Zip Code  Crime Sum  Crime Ratio
# 0          NaN       66.0     0.027836
# 1          NaN      436.0     0.104858
# 2          NaN       34.0     0.050445
# 3      35007.0     1178.0     0.034525
# 4      35950.0      972.0     0.042470
# ...        ...        ...          ...
# 8360       NaN      479.0     0.024599
# 8361       NaN       36.0     0.013373
# 8362       NaN      216.0     0.035133
# 8363       NaN       30.0     0.033186
# 8364       NaN       52.0     0.010806
#
# [8364 rows x 16 columns]
